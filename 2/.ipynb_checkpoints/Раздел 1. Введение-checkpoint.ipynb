# %% [markdown]
# # Тест: правильная скорость роста

# %% [markdown]
# ## Отметьте все верные утверждения.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import limit, Symbol, oo, log, sqrt, factorial

# %%
# Равенство 1 - Омега: True, т.к. expr = oo
x = Symbol('x')
expr = sqrt(x)/log(x, 2)**3
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): oo

# %%
# Равенство 2 - О-большое: False, т.к. expr = oo
x = Symbol('x')
expr = (x**2/log(x, 3)) / (x*log(x, 2)**2)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): oo

# %%
# Равенство 3 - О-большое: True, т.к. expr = 0
x = Symbol('x')
expr = (x * 2**x) / (3**x)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): 0

# %%
# Равенство 4 - О-большое: True, т.к. expr = constant
x = Symbol('x')
expr = (2**x) / (2**(x+1))
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): 1/2

# %%
# Равенство 5 - О-большое: True, т.к. expr = 0
x = Symbol('x')
expr = (x**0.5) / (5**log(x, 2))
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): 0

# %%
# Равенство 6 - Тета: True, т.к. expr = constant
x = Symbol('x')
expr = (2**x) / (2**(x+1))
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): 1/2

# %%
# Равенство 7 - О-большое: False, т.к. expr = oo
x = Symbol('x')
expr = factorial(x) / (2**x)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): oo

# %%
# Примеры для Тетта

# %%
x = Symbol('x')
expr = (x**2)/(3*x**2 + 10*x)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): 1/3

# %%
x = Symbol('x')
expr = (x*log(x, 2))/(x**2)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): 0

# %%
# Примеры для Омега

# %%
x = Symbol('x')
expr = (0.5*x**2)/(x**2)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): 0.500000000000000

# %%
x = Symbol('x')
expr = (x**3)/(x**2)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): oo

# %%
# Примеры для О-большого

# %%
x = Symbol('x')
expr = (x**2 + 2*x) / (0.5*x**2)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): 2.00000000000000

# %%
x = Symbol('x')
expr = (x**2)/(x**25)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): 0

# %%
x = Symbol('x')
expr = (x*log(x))/(x)
limit_expr = limit(expr, x, oo) # 3-й аргумент к чему стремится x (0 - нуль, oo - плюс бесконечность)
print(f"Limit of the expression tends to oo (infinity): {limit_expr}")
# Out:
# Limit of the expression tends to oo (infinity): oo

# %% [markdown]
# ## Упорядочите данные семь функций по возрастанию скорости роста (сверху — медленнее всего растущая функция, снизу — быстрее всего растущая).
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = np.linspace(1, 3, 20)
y1 = n * (np.log(n)/np.log(2))**3
y2 = n**3
y3 = n**0.5
y4 = 4**n
y5 = n**0.3
y6 = np.log(n)/np.log(5)
y7 = n * (np.log(n)/np.log(2))

fig, ax = plt.subplots(figsize=(10,8))

ax.plot(n, y1, linewidth=2.0)
ax.plot(n, y2, linewidth=2.0)
ax.plot(n, y3, linewidth=2.0)
ax.plot(n, y4, linewidth=2.0)
ax.plot(n, y5, linewidth=2.0)
ax.plot(n, y6, linewidth=2.0)
ax.plot(n, y7, linewidth=2.0)
ax.legend(['y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'])

plt.show()

# Определили быстрее всего растущие функции y4, y2, y1, y7

# %%
# Строим для остальных
n = np.linspace(1, 20, 20)
y3 = n**0.5
y5 = n**0.3
y6 = np.log(n)/np.log(5)

fig, ax = plt.subplots(figsize=(10,8))

ax.plot(n, y3, linewidth=2.0)
ax.plot(n, y5, linewidth=2.0)
ax.plot(n, y6, linewidth=2.0)
ax.legend(['y3', 'y5', 'y6'])

plt.show()

# %% [markdown]
# # Тест повышенной сложности: правильная скорость роста

# %% [markdown]
# ### Упорядочите данные функции по возрастанию скорости роста (сверху — медленнее всего растущая функция, снизу — быстрее всего растущая).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ответ - порядок функций по возрастанию: 18, 12, 17, 7, 3, 4, 16,  9, 10,  1, 15, 14, 6, 11, 8, 2, 5, 13

# %% [markdown]
# ### Решение 1

# %%
from sympy import limit, Symbol, oo, log, sqrt, factorial
from sympy.core.numbers import Infinity

n = Symbol('n')

y1 = (1, 7**log(n, 2))
y2 = (2, 2**(3*n))
y3 = (3, n**0.5)
y4 = (4, n / log(n, 5))
y5 = (5, factorial(n))
y6 = (6, n**(n**0.5))
y7 = (7, log(n, 2)**2)
y8 = (8, 4**n)
y9 = (9, 3**log(n, 2))
y10 = (10, n**2)
y11 = (11, 2**n)
y12 = (12, log(n, 4)**0.5)
y13 = (13, 2**(2**n))
y14 = (14, n**log(n, 2))
y15 = (15, log(n, 2)**log(n, 2))
y16 = (16, log(factorial(n), 2))
y17 = (17, log(n, 3))
y18 = (18, log(log(n, 2), 2))

expr = list([y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,y16,y17,y18])


# Bubble sort

indexOfLastUnsortedElement = len(expr)

while True:
    
    print(indexOfLastUnsortedElement)
    swapped = False
    for i in range (1, indexOfLastUnsortedElement):
        limit_expr = limit(expr[i-1][1]/expr[i][1], n, oo)
        if isinstance(limit_expr, Infinity):
            expr[i], expr[i-1] = expr[i-1], expr[i]
            swapped = True

    indexOfLastUnsortedElement -= 1
            
    if not swapped:
        break
        
print(expr)

# %% [markdown]
# ### Решение 2

# %%
from sympy import Symbol, limit, log, factorial, oo

'''
класс - обертка для выражения sympy
для работы достаточно реализовать перегрузку оператора __lt__ (хотя надо бы и __le__ и остальные тоже перегружать)
'''
class ExpessionWrapper:
    def __init__(self, expr):
        self.expression = expr
    def __lt__(self, other):
        return limit(self.expression / other.expression, n, oo) == 0

if __name__ == "__main__":
    n = Symbol('n')

    funcs = [7**log(n, 2), 2**(3*n), n**0.5, n / log(n, 5), factorial(n), n**(n**0.5), log(n, 2)**2,
        4**n, 3**log(n, 2), n**2, 2**n, log(n, 4)**0.5, 2**(2**n), n**log(n, 2), log(n, 2)**log(n, 2),
        log(factorial(n), 2), log(n, 3), log(log(n, 2), 2)]

    for func in sorted(list(map(lambda x: ExpessionWrapper(x), funcs))):
        print(func.expression)
